# %%
import pandas as pd

# %%
df = pd.read_csv('./bird_strikes_clean.csv')
df
# Out:
#        altitude_bin  aircraft_make_model  wildlife_number_struck_actual  \
# 0                 0                    0                              3
# 1                 0                    0                             10
# 2                 0                    0                              4
# 3                 0                    0                              5
# 4                 0                    1                              6
# ...             ...                  ...                            ...
# 25553             0                  313                              1
# 25554             0                  349                              1
# 25555             0                  248                              1
# 25556             0                  350                              1
# 25557             0                  248                              1
#
#        effect_impact_to_flight  effect_indicated_damage  \
# ...

# %%
ds_bst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   altitude_bin                       25558 non-null  int64
#  1   aircraft_make_model                25558 non-null  int64
#  2   wildlife_number_struck_actual      25558 non-null  int64
#  3   effect_impact_to_flight            25558 non-null  int64
#  4   effect_indicated_damage            25558 non-null  int64
#  5   aircraft_number_of_engines         25558 non-null  float64
#  6   when_phase_of_flight               25558 non-null  int64
#  7   conditions_precipitation           25558 non-null  int64
#  8   remains_of_wildlife_collected      25558 non-null  int64
#  9   wildlife_size                      25558 non-null  int64
#  10  conditions_sky                     25558 non-null  int64
# ...
